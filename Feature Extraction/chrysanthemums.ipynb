# %% [markdown]
# # Feature Extraction of Chrysanthemums

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2

# %% [markdown]
# ## Non-parametric Segmentation from previous activity

# %%
def RGI(image):
    R = np.float_(image[:,:,0])
    G = np.float_(image[:,:,1])
    B = np.float_(image[:,:,2])
    
    I = np.float_(R+G+B)
    I[I==0] = 100000

    r = R/I
    g = G/I
    b = B/I
    
    return np.float_(r),np.float_(g),np.float_(b)

# %%
def non_para(bins,p_r,p_g,im_r,im_g):
    r_int = np.round(p_r*(bins-1))
    g_int = np.round(p_g*(bins-1))
    
    R_int = np.round(im_r*(bins-1)+1)
    G_int = np.round(im_g*(bins-1)+1)
    
    return r_int,g_int,R_int,G_int

# %%
def segmentation(whole,patch,Bin):
    im_r,im_g,im_b = RGI(whole)
    p_r,p_g,p_b = RGI(patch)
    
    bins = Bin
    r_int,g_int,R_int,G_int = non_para(bins,p_r,p_g,im_r,im_g)
    h = plt.hist2d(r_int.flatten()/bins,g_int.flatten()/bins,bins=bins,range=[[0,1],[0,1]],cmap='gray')[0]
    plt.close()
    new_img = np.zeros((whole.shape[0],whole.shape[1]))

    for i in range(whole.shape[0]-1):
        for j in range(whole.shape[1]-1):
            new_img[i][j] += h[np.int(R_int[i][j])-1,np.int(G_int[i][j])-1]
    new_img = np.round(255*new_img/np.amax(new_img)).astype('uint8')
    
    plt.figure(figsize=(8,6))
    plt.imshow(new_img,cmap='gray')
#     plt.savefig('chrysanthemums_nonpara.png',dpi=300,bbox_inches='tight')
    plt.show()
    
    return new_img

# %% [markdown]
# ## Perform Morphological Operations (Opening) to clean detected flowers

# %%
def clean(new_img):
    cleaning = np.copy(new_img)
    kernel = cv2.getStructuringElement(cv2.MORPH_CROSS,(5,5))
    closing = cv2.morphologyEx(cleaning, cv2.MORPH_CLOSE, kernel, iterations=2)
    
    plt.figure(figsize=(14,10))
    plt.imshow(closing,cmap='gray')#,plt.xticks([]),plt.yticks([])
#     plt.savefig('chrysanthemums_cleaning.png',dpi=300,bbox_inches='tight')
    
    return closing

# %%
whole = plt.imread('chrysanthemums.jpg')
patch = plt.imread('chrysanthemum_patch.jpg')

new_image = segmentation(whole,patch,8)
closing = clean(new_image)

# %% [markdown]
# ## Finding contours of flowers using binarized image

# %%
contours, hierarchy = cv2.findContours(closing, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
cont_image = np.copy(whole)

im_with_contours = cv2.drawContours(cont_image, contours, -1, (1,0,0), 2)

plt.figure(figsize=(14,10))
plt.imshow(im_with_contours)
# plt.savefig('chrysanthemums_contour.png',dpi=300,bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Fitting an eclipse to each contour and calculating eccentricity from ellipse

# %%
eccent = []
cent = []
im_with_ellipse = np.copy(whole)

for c in contours:
    if len(c) < 30:
        continue
    
    moments = cv2.moments(c)
    cx = moments['m10']/moments['m00']
    cy = moments['m01']/moments['m00']
    
    ellipse = cv2.fitEllipse(c)
    center,axes,orientation = ellipse
    maj_axis = max(axes)
    min_axis = min(axes)
    eccentricity = np.sqrt(1-((min_axis/maj_axis)**2))
    
    eccent.append(eccentricity)
    cent.append(np.array([cx,cy],dtype=int))
    
    im_with_ellipse = cv2.ellipse(im_with_ellipse,ellipse,(0,0,1),2)

# %%
plt.figure(figsize=(14,12))
plt.imshow(im_with_ellipse)
# plt.savefig('chrysanthemum_ellipse.png',dpi=300,bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Calculate nomalized chromaticity coordinates (NCC) of Centroids

# %%
r,g,b = RGI(whole)
centroid_r = []
centroid_g = []
centroid_b = []

# %%
plt.figure(figsize=(12,10))
plt.imshow(im_with_ellipse)

for p in cent:
    plt.scatter(p[0],p[1],c='black',s=50)
    centroid_r.append(r[p[1],p[0]])
    centroid_g.append(g[p[1],p[0]])
    centroid_b.append(b[p[1],p[0]])

# plt.savefig('chrysanthemums_centroid.png',dpi=300,bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Create DataFrame of Features from eccentricity of eclipses and NCC of centroids

# %%
features = pd.DataFrame(columns=['r','g','b','eccentricity'])
features['r'] = centroid_r
features['g'] = centroid_g
features['b'] = centroid_b
features['eccentricity'] = eccent

# %%
# features.to_csv('chrysanthemum_features.csv')
